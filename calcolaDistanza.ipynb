# %%
import requests
from math import radians, sin, cos, sqrt, atan2
import pandas as pd
import time
import numpy as np

def get_coordinates(postal_code, country):
    """
    Ottiene le coordinate geografiche di un codice postale per IT o US
    """
    if country not in ['IT', 'US']:
        raise ValueError(f"Paese non supportato: {country}")
    
    # Costruisce la query appropriata per il paese
    if country == 'IT':
        query = f"{postal_code}, Italy"
    else:
        query = f"{postal_code}, United States"
    
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": query,
        "format": "json",
        "limit": 1,
        "countrycodes": country.lower()
    }
    headers = {
        "User-Agent": "DistanceCalculator/1.0"
    }
    
    try:
        response = requests.get(url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        if not data:
            raise ValueError(f"Codice postale non trovato: {postal_code} in {country}")
        
        # Rispetta il rate limiting di Nominatim
        time.sleep(1)
        
        return {
            "lat": float(data[0]["lat"]),
            "lon": float(data[0]["lon"])
        }
    except requests.exceptions.RequestException as e:
        raise Exception(f"Errore nella richiesta API: {str(e)}")

def calculate_distance(coord1, coord2):
    """
    Calcola la distanza in kilometri tra due punti usando la formula di Haversine
    """
    R = 6371  # Raggio della Terra in km
    
    lat1, lon1 = radians(coord1["lat"]), radians(coord1["lon"])
    lat2, lon2 = radians(coord2["lat"]), radians(coord2["lon"])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    
    return distance

def process_csv(file_path):
    """
    Legge il CSV e aggiorna le distanze mancanti nella colonna DECLARED_DISTANCE_KM
    per spedizioni IT-IT, US-US, IT-US e US-IT
    """
    try:
        # Legge il CSV
        df = pd.read_csv(file_path)
        
        # Se non esiste la colonna DECLARED_DISTANCE_KM, la crea
        if 'DECLARED_DISTANCE_KM' not in df.columns:
            df['DECLARED_DISTANCE_KM'] = np.nan
        
        # Filtra le spedizioni IT e US
        mask = (
            ((df['DEPARTURE_COUNTRY'].isin(['IT', 'US'])) & 
             (df['ARRIVAL_COUNTRY'].isin(['IT', 'US'])))
        )
        valid_rows = df[mask].index
        
        if len(valid_rows) == 0:
            raise ValueError("Nessuna spedizione IT/US trovata nel CSV")
        
        # Statistiche iniziali
        stats = {
            'IT-IT': len(df[(df['DEPARTURE_COUNTRY'] == 'IT') & (df['ARRIVAL_COUNTRY'] == 'IT')]),
            'US-US': len(df[(df['DEPARTURE_COUNTRY'] == 'US') & (df['ARRIVAL_COUNTRY'] == 'US')]),
            'IT-US': len(df[(df['DEPARTURE_COUNTRY'] == 'IT') & (df['ARRIVAL_COUNTRY'] == 'US')]),
            'US-IT': len(df[(df['DEPARTURE_COUNTRY'] == 'US') & (df['ARRIVAL_COUNTRY'] == 'IT')])
        }
        
        print("Spedizioni trovate:")
        for route, count in stats.items():
            print(f"{route}: {count}")
        
        # Conta quante distanze devono essere calcolate
        missing_distances = df.loc[valid_rows, 'DECLARED_DISTANCE_KM'].isna().sum()
        print(f"\nDistanze da calcolare: {missing_distances}")
        
        # Elabora le righe con distanza mancante
        rows_processed = 0
        for idx in valid_rows:
            # Salta se la distanza è già presente
            if pd.notna(df.at[idx, 'DECLARED_DISTANCE_KM']):
                continue
                
            try:
                departure_code = str(df.at[idx, 'DEPARTURE_ZIPCODE'])
                arrival_code = str(df.at[idx, 'ARRIVAL_ZIPCODE'])
                departure_country = df.at[idx, 'DEPARTURE_COUNTRY']
                arrival_country = df.at[idx, 'ARRIVAL_COUNTRY']
                
                # Ottiene le coordinate
                coord1 = get_coordinates(departure_code, departure_country)
                coord2 = get_coordinates(arrival_code, arrival_country)
                
                # Calcola la distanza
                distance = calculate_distance(coord1, coord2)
                df.at[idx, 'DECLARED_DISTANCE_KM'] = round(distance, 2)
                
                rows_processed += 1
                print(f"Elaborata riga {idx + 1}: {departure_code}({departure_country}) -> "
                      f"{arrival_code}({arrival_country}) = {distance:.2f} km ({rows_processed}/{missing_distances})")
                
                # Salva periodicamente ogni 10 righe elaborate
                if rows_processed % 10 == 0:
                    df.to_csv(file_path, index=False)
                    print(f"Salvaggio intermedio effettuato dopo {rows_processed} righe")
                
            except Exception as e:
                print(f"Errore nella riga {idx + 1}: {str(e)}")
                continue
        
        # Salvataggio finale
        df.to_csv(file_path, index=False)
        print(f"\nFile aggiornato salvato in: {file_path}")
        
        # Mostra statistiche finali per ogni tipo di percorso
        print("\nStatistiche delle distanze per tipo di percorso:")
        for dep_country in ['IT', 'US']:
            for arr_country in ['IT', 'US']:
                route_mask = (df['DEPARTURE_COUNTRY'] == dep_country) & (df['ARRIVAL_COUNTRY'] == arr_country)
                route_distances = df[route_mask]['DECLARED_DISTANCE_KM'].dropna()
                
                if not route_distances.empty:
                    print(f"\n{dep_country}-{arr_country}:")
                    print(f"Numero spedizioni: {len(route_distances)}")
                    print(f"Distanza media: {route_distances.mean():.2f} km")
                    print(f"Distanza massima: {route_distances.max():.2f} km")
                    print(f"Distanza minima: {route_distances.min():.2f} km")
        
        return df
        
    except Exception as e:
        raise Exception(f"Errore nell'elaborazione del CSV: {str(e)}")

# Esempio di utilizzo
if __name__ == "__main__":
    try:
        input_file = input("Inserisci il percorso del file CSV da elaborare: ")
        results = process_csv(input_file)
        
    except Exception as e:
        print(f"Errore: {str(e)}")
# Out:
# Inserisci il percorso del file CSV da elaborare:  cleaned_dataset.csv
# Spedizioni trovate:
# IT-IT: 11515
# US-US: 2223
# IT-US: 569
# US-IT: 0
#
# Distanze da calcolare: 1578
# Errore nella riga 6389: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x124227770>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6390: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0b90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6392: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10013%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a1450>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6393: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=85018%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a16d0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6394: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=34231%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6395: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19006%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6397: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=11568%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6398: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19081%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a20d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6404: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=77056%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a2350>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6410: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=85249%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a25d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6430: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7960%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a2850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6432: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=75225%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a2ad0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6435: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=78701%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a2d50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6438: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=85253%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12426b390>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6439: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=85253%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b750>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6440: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33154%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426afd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6441: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33154%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6442: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33154%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bb10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6443: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=90004%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6444: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2116%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d42d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6445: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=30319%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6467: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243d47d0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6468: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6469: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7675%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6480: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33154%2C+United+States&format=json&limit=1&countrycodes=us (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243d4f50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6483: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33323%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6484: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2540%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6485: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=77019%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6486: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=90036%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6487: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=31326%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6492: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bc50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6590: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b9d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6668: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426a850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6669: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12426b4d0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6675: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6711: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6720: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a02d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6745: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6746: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a07d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6748: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6759: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6780: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a0f50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6823: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a11d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6835: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6851: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a16d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6865: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6870: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a1bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6871: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6878: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b750>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6880: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426afd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6884: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6885: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bb10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6886: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a8050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6888: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a82d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6892: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a8550>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6893: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a87d0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6919: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a8a50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6920: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a8cd0>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6923: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1243a8f50>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=None)'))
# Errore nella riga 6928: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a91d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6932: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=8540%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a9450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6940: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a96d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6943: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a9950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6948: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243a9bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6949: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bc50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6955: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b9d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6971: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426a850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 6981: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b4d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7111: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7118: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7122: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d42d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7153: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7233: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10065%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d47d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7241: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7243: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10065%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7249: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4f50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7251: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10065%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7254: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63076%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7255: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10022%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7299: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10001%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7304: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=63811%2C+Italy&format=json&limit=1&countrycodes=it (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7307: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=10001%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7314: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2116%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7319: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b4d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7321: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426a850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7322: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b9d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7323: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=92626%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bc50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7324: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7329: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7330: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7331: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7332: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7333: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7601%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4f50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7334: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7335: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7336: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=60611%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d47d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7337: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7339: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=60611%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d42d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7341: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7343: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bb10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7345: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7346: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426afd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7347: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=92626%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b750>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7349: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7351: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d42d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7352: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=77056%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7353: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d47d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7355: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19086%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7356: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7357: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4f50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7358: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7360: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7361: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7362: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7363: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7364: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7366: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7367: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b750>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7368: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=92626%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426afd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7370: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=80013%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7373: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bb10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7374: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7375: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7377: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7378: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5450>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 7379: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ...
# Errore nella riga 14257: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4410>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14258: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=11691%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4690>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14259: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=85224%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4910>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14260: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4b90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14261: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=90210%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6c10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14262: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=90210%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14264: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14267: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14268: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=92626%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14270: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14271: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=19104%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d47d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14272: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4550>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14273: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d42d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14274: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d56d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14276: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5d10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14277: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14278: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d51d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14279: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5810>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14282: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6710>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14283: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6990>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14284: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6ad0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14285: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6e90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14286: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=94973%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426a850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14288: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=90291%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b4d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14290: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426bb10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14291: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d6210>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14292: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14293: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14294: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d60d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14295: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d65d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14296: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7008%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5310>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14297: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=48238%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5090>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14298: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33578%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5950>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14299: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=91501%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d5a90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14301: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=33154%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4190>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14302: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=20852%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4410>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14303: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=20001%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4690>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14304: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=66205%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4910>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14306: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=20120%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1243d4b90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Errore nella riga 14307: Errore nella richiesta API: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2420%2C+United+States&format=json&limit=1&countrycodes=us (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12426b390>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# File aggiornato salvato in: cleaned_dataset.csv
#
# Statistiche delle distanze per tipo di percorso:
#
# IT-IT:
# Numero spedizioni: 11513
# Distanza media: 352.65 km
# Distanza massima: 1090.61 km
# Distanza minima: 0.64 km
#
# IT-US:
# Numero spedizioni: 260
# Distanza media: 8489.56 km
# Distanza massima: 12825.00 km
# Distanza minima: 6459.29 km
#
# US-US:
# Numero spedizioni: 1011
# Distanza media: 1589.15 km
# Distanza massima: 6845.34 km
# Distanza minima: 0.81 km
